# %%
import pandas as pd

r_cols = ['user_id', 'movie_id', 'rating']
ratings = pd.read_csv('D:/DataScience/DataScience-Python3/ml-100k/u.data', sep='\t', names=r_cols, usecols=range(3))

m_cols = ['movie_id', 'title']
movies = pd.read_csv('D:/DataScience/DataScience-Python3/ml-100k/u.item', sep='|', names=m_cols, usecols=range(2), encoding="ISO-8859-1")

ratings = pd.merge(movies, ratings)

# %%
ratings.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3

# %%
movieRatings = ratings.pivot_table(index=['user_id'],columns=['title'],values='rating')
movieRatings.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
starWarsRatings = movieRatings['12 Angry Men (1957)']
starWarsRatings.head(20)
# Out:
# user_id
# 0     NaN
# 1     5.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     4.0
# 7     4.0
# 8     NaN
# 9     NaN
# 10    5.0
# 11    NaN
# 12    NaN
# 13    4.0
# 14    NaN
# 15    NaN
# 16    5.0
# 17    NaN
# 18    3.0
# 19    NaN
# Name: 12 Angry Men (1957), dtype: float64

# %%
similarMovies = movieRatings.corrwith(starWarsRatings) #movie rating correlated with starwars
similarMovies = similarMovies.dropna()
df = pd.DataFrame(similarMovies)
df.head(15)
# Out:
# C:\Users\Palugudi\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3175: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\Palugudi\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)
#                                               0
# title
# 'Til There Was You (1997)             -0.500000
# 101 Dalmatians (1996)                 -0.049890
# 12 Angry Men (1957)                    1.000000
# 187 (1997)                             0.666667
# 2 Days in the Valley (1996)            0.256625
# 20,000 Leagues Under the Sea (1954)    0.274772
# 2001: A Space Odyssey (1968)           0.178848
# 39 Steps, The (1935)                   0.457176
# 8 1/2 (1963)                           0.635698
# Above the Rim (1994)                   1.000000
# Absolute Power (1997)                 -0.163455
# Abyss, The (1989)                      0.045374
# ...

# %%
similarMovies.sort_values(ascending=False)
# Out:
# title
# Spirits of the Dead (Tre passi nel delirio) (1968)          1.000000
# Jefferson in Paris (1995)                                   1.000000
# Double Happiness (1994)                                     1.000000
# Nina Takes a Lover (1994)                                   1.000000
# Dream With the Fishes (1997)                                1.000000
# Run of the Country, The (1995)                              1.000000
# Screamers (1995)                                            1.000000
# Pyromaniac's Love Story, A (1995)                           1.000000
# FairyTale: A True Story (1997)                              1.000000
# Stalker (1979)                                              1.000000
# Bad Moon (1996)                                             1.000000
# Surviving Picasso (1996)                                    1.000000
# The Innocent (1994)                                         1.000000
# ...

# %%
import numpy as np
movieStats = ratings.groupby('title').agg({'rating': [np.size, np.mean]})
movieStats.head(10)
# Out:
#                                             rating
#                                               size      mean
# title
# 'Til There Was You (1997)                        9  2.333333
# 1-900 (1994)                                     5  2.600000
# 101 Dalmatians (1996)                          109  2.908257
# 12 Angry Men (1957)                            125  4.344000
# 187 (1997)                                      41  3.024390
# 2 Days in the Valley (1996)                     93  3.225806
# 20,000 Leagues Under the Sea (1954)             72  3.500000
# 2001: A Space Odyssey (1968)                   259  3.969112
# 3 Ninjas: High Noon At Mega Mountain (1998)      5  1.000000
# 39 Steps, The (1935)                            59  4.050847

# %%
popularMovies = movieStats['rating']['size'] >= 100
movieStats[popularMovies].sort_values([('rating', 'mean')], ascending=False)[:15]
# Out:
#                                        rating
#                                          size      mean
# title
# Close Shave, A (1995)                     112  4.491071
# Schindler's List (1993)                   298  4.466443
# Wrong Trousers, The (1993)                118  4.466102
# Casablanca (1942)                         243  4.456790
# Shawshank Redemption, The (1994)          283  4.445230
# Rear Window (1954)                        209  4.387560
# Usual Suspects, The (1995)                267  4.385768
# Star Wars (1977)                          584  4.359589
# 12 Angry Men (1957)                       125  4.344000
# Citizen Kane (1941)                       198  4.292929
# To Kill a Mockingbird (1962)              219  4.292237
# One Flew Over the Cuckoo's Nest (1975)    264  4.291667
# Silence of the Lambs, The (1991)          390  4.289744
# North by Northwest (1959)                 179  4.284916
# Godfather, The (1972)                     413  4.283293

# %%
df = movieStats[popularMovies].join(pd.DataFrame(similarMovies, columns=['similarity']))
# Out:
# C:\Users\Palugudi\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:543: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)

# %%
df.head()
# Out:
#                            (rating, size)  (rating, mean)  similarity
# title
# Contact (1997)                        509        3.803536    0.022265
# Fargo (1996)                          508        4.155512    0.098676
# Return of the Jedi (1983)             507        4.007890   -0.026169
# Star Wars (1977)                      584        4.359589    0.184289

# %%
df.sort_values(['similarity'], ascending=False)[:15]
# Out:
#                            (rating, size)  (rating, mean)  similarity
# title
# Star Wars (1977)                      584        4.359589    0.184289
# Fargo (1996)                          508        4.155512    0.098676
# Contact (1997)                        509        3.803536    0.022265
# Return of the Jedi (1983)             507        4.007890   -0.026169

# %%
popularMovies = movieStats['rating']['size'] >= 500
movieStats[popularMovies].sort_values([('rating', 'mean')], ascending=False)[:15]
# Out:
#                           rating
#                             size      mean
# title
# Star Wars (1977)             584  4.359589
# Fargo (1996)                 508  4.155512
# Return of the Jedi (1983)    507  4.007890
# Contact (1997)               509  3.803536

# %%
df = movieStats[popularMovies].join(pd.DataFrame(similarMovies, columns=['similarity']))
# Out:
# C:\Users\Palugudi\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:543: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)

# %%
df.head()
# Out:
#                            (rating, size)  (rating, mean)  similarity
# title
# Contact (1997)                        509        3.803536    0.022265
# Fargo (1996)                          508        4.155512    0.098676
# Return of the Jedi (1983)             507        4.007890   -0.026169
# Star Wars (1977)                      584        4.359589    0.184289

# %%
df.sort_values(['similarity'], ascending=False)[:15]
# Out:
#                            (rating, size)  (rating, mean)  similarity
# title
# Star Wars (1977)                      584        4.359589    0.184289
# Fargo (1996)                          508        4.155512    0.098676
# Contact (1997)                        509        3.803536    0.022265
# Return of the Jedi (1983)             507        4.007890   -0.026169

# %%
userRatings = ratings.pivot_table(index=['user_id'],columns=['title'],values='rating')
userRatings.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
corrMatrix = userRatings.corr()
corrMatrix.head(15)
# Out:
# title                                        'Til There Was You (1997)  \
# title
# 'Til There Was You (1997)                                     1.000000
# 1-900 (1994)                                                       NaN
# 101 Dalmatians (1996)                                        -1.000000
# 12 Angry Men (1957)                                          -0.500000
# 187 (1997)                                                   -0.500000
# 2 Days in the Valley (1996)                                   0.522233
# 20,000 Leagues Under the Sea (1954)                                NaN
# 2001: A Space Odyssey (1968)                                 -0.426401
# 3 Ninjas: High Noon At Mega Mountain (1998)                        NaN
# 39 Steps, The (1935)                                               NaN
# 8 1/2 (1963)                                                       NaN
# 8 Heads in a Duffel Bag (1997)                                     NaN
# ...

# %%
myRatings = userRatings.loc[0].dropna()
myRatings
# Out:
# title
# Empire Strikes Back, The (1980)    5.0
# Gone with the Wind (1939)          1.0
# Star Wars (1977)                   5.0
# Name: 0, dtype: float64

# %%
simCandidates = pd.Series()
for i in range(0, len(myRatings.index)):
    print ("Adding sims for " + myRatings.index[i] + "...")
    # Retrieve similar movies to this one that I rated
    sims = corrMatrix[myRatings.index[i]].dropna()
    # Now scale its similarity by how well I rated this movie
    sims = sims.map(lambda x: x * myRatings[i])
    # Add the score to the list of similarity candidates
    simCandidates = simCandidates.append(sims)
    
#Glance at our results so far:
print ("sorting...")
simCandidates.sort_values(inplace = True, ascending = False)
print (simCandidates.head(40))
# Out:
# Adding sims for Empire Strikes Back, The (1980)...
# Adding sims for Gone with the Wind (1939)...
# Adding sims for Star Wars (1977)...
# sorting...
# Man of the Year (1995)                                                               5.0
# Hollow Reed (1996)                                                                   5.0
# Commandments (1997)                                                                  5.0
# Golden Earrings (1947)                                                               5.0
# Prisoner of the Mountains (Kavkazsky Plennik) (1996)                                 5.0
# Good Man in Africa, A (1994)                                                         5.0
# Golden Earrings (1947)                                                               5.0
# Full Speed (1996)                                                                    5.0
# Line King: Al Hirschfeld, The (1996)                                                 5.0
# ...

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()

# %%
simCandidates.head(10)
# Out:
# 'Til There Was You (1997)              7.022253
# 1-900 (1994)                          -7.952042
# 101 Dalmatians (1996)                  1.696960
# 12 Angry Men (1957)                    1.455519
# 187 (1997)                             1.725711
# 2 Days in the Valley (1996)           -0.560865
# 20,000 Leagues Under the Sea (1954)    2.571082
# 2001: A Space Odyssey (1968)           1.867302
# 39 Steps, The (1935)                   1.252457
# 8 1/2 (1963)                          -0.901679
# dtype: float64

# %%
filteredSims = simCandidates.drop(myRatings.index)
filteredSims.head(10)
# Out:
# 'Til There Was You (1997)              7.022253
# 1-900 (1994)                          -7.952042
# 101 Dalmatians (1996)                  1.696960
# 12 Angry Men (1957)                    1.455519
# 187 (1997)                             1.725711
# 2 Days in the Valley (1996)           -0.560865
# 20,000 Leagues Under the Sea (1954)    2.571082
# 2001: A Space Odyssey (1968)           1.867302
# 39 Steps, The (1935)                   1.252457
# 8 1/2 (1963)                          -0.901679
# dtype: float64
