# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
import pylab as pl
from itertools import cycle

iris = load_iris()

numSamples, numFeatures = iris.data.shape 
print(numSamples)
print(numFeatures)
print(list(iris.target_names))
# Out:
# 150
# 4
# ['setosa', 'versicolor', 'virginica']

# %%
X = iris.data
pca = PCA(n_components=2, whiten=True).fit(X) #num of dimensions 2 and fit into data set (here we set 2D instead of 4D)
X_pca = pca.transform(X)

# %%
print (pca.components_)
# Out:
# [[ 0.36158968 -0.08226889  0.85657211  0.35884393]
#  [ 0.65653988  0.72971237 -0.1757674  -0.07470647]]

# %%
print(pca.explained_variance_ratio_)
print(sum(pca.explained_variance_ratio_))
# Out:
# [0.92461621 0.05301557]
# 0.9776317750248034

# %%
# %matplotlib inline
from pylab import *

colors = cycle('rgb')
target_ids = range(len(iris.target_names))
pl.figure()
for i, c, label in zip(target_ids, colors, iris.target_names):
    pl.scatter(X_pca[iris.target == i, 0], X_pca[iris.target == i, 1],
        c=c, label=label)
pl.legend()
pl.show()

# %%
X = iris.data
pca = PCA(n_components=1, whiten=True).fit(X) #num of dimensions 2 and fit into data set (here we set 2D instead of 4D)
X_pca = pca.transform(X)

# %%
print(pca.components_)
# Out:
# [[ 0.36158968 -0.08226889  0.85657211  0.35884393]]

# %%
print(pca.explained_variance_ratio_)
print(sum(pca.explained_variance_ratio_))
# Out:
# [0.92461621]
# 0.9246162071742683

# %%
# %matplotlib inline
from pylab import *

colors = cycle('rgb')
target_ids = range(len(iris.target_names))
pl.figure()
for i, c, label in zip(target_ids, colors, iris.target_names):
    pl.scatter(X_pca[iris.target == i, 0], X_pca[iris.target == i, 0],
        c=c, label=label)
pl.legend()
pl.show()

# %%
X = iris.data
pca = PCA(n_components=3, whiten=True).fit(X) #num of dimensions 2 and fit into data set (here we set 2D instead of 4D)
X_pca = pca.transform(X)

# %%
print(pca.components_)
# Out:
# [[ 0.36158968 -0.08226889  0.85657211  0.35884393]
#  [ 0.65653988  0.72971237 -0.1757674  -0.07470647]
#  [-0.58099728  0.59641809  0.07252408  0.54906091]]

# %%
print(pca.explained_variance_ratio_)
print(sum(pca.explained_variance_ratio_))
# Out:
# [0.92461621 0.05301557 0.01718514]
# 0.9948169145498101

# %%
# %matplotlib inline
from pylab import *

colors = cycle('rgb')
target_ids = range(len(iris.target_names))
pl.figure()
for i, c, label in zip(target_ids, colors, iris.target_names):
    pl.scatter(X_pca[iris.target == i, 0], X_pca[iris.target == i, 2],
        c=c, label=label)
pl.legend()
pl.show()
